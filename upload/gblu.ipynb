# %%
# Loading the Libraries
from dotenv import load_dotenv
load_dotenv()
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import os,glob
GBLU_PATH = '/Users/boristsao/Documents/Projects/GBLU/upload/data/gblu_2022.xlsx'

# %%
data = pd.read_excel(GBLU_PATH, sheet_name="2022", header=0)
data.head()
# Out:
#        Country Flag Month of Update Employer Action Required?  \
# 0  Afghanistan  NaN          2022-5                       Yes
# 1    Australia  NaN          2022-5                       Yes
# 2       Canada  NaN          2022-5                       Yes
# 3        Chile  NaN          2022-5                       Yes
# 4       Greece  NaN          2022-5                       Yes
#
#                           Legislative Update Summary          HR Area  \
# 0  Roundup: Employer resources on minimum wage in...           Career
# 1     ASIC finalizes IDR data reporting requirements           Wealth
# 2  Employers to disclose electronic monitoring, i...  Career — Health
# 3                             Minimum wage increased           Career
# 4     Minimum wage increased for second time in 2022           Career
#
#                 Law in Force  \
# 0      Effective dates vary.
# 1             Beginning 2023
# 2  Effective dates vary.\n\n
# 3       Currently effective
# 4       Currently effective
#
#                                              New Law  \
# 0  In April 2021, President Joe Biden signed an e...
# 1  Final requirements from the Australian Securit...
# 2  Bill 88, the Working for Workers Act 2022, whi...
# 3  The monthly minimum wage increased on 1 Januar...
# 4  On 1 May 2022, Greece’s monthly minimum wage i...
#
#                                  Impact on Employers  \
# 0  Employers should review the changes, as they w...
# 1  Employers should review the changes, as they w...
# 2  Employers should review the changes, as they w...
# 3  Employers should review the changes, as they w...
# 4  Employers should review the changes, as they w...
#
#                                   More Information 1 More Information 2  \
# 0  Title: GRIST, regularly updated \nLink Name: G...                NaN
# 1                                                NaN                NaN
# 2  Title: Bill 88, the Working for Workers Act, 2...                NaN
# 3  Title: Announcement (Spanish) (Official Gazett...                NaN
# 4  Title: Minimum wage rises to €713 on May 1 (Ek...                NaN
#
#   More Information 3
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN

# %%
new_columns = ['country', 'flag', 'month_of_update', 'employer_action_required',
       'legislative_update_summary', 'hr_area', 'law_in_force', 'new_law',
       'impact_on_employers', 'more_info_1', 'more_info_2', 'more_info_3']
columns_dict = {}
for col in data.columns:
    columns_dict[col] = new_columns[data.columns.get_loc(col)]
data.rename(columns=columns_dict, inplace=True)
data.head()
# Out:
#        country flag month_of_update employer_action_required  \
# 0  Afghanistan  NaN          2022-5                      Yes
# 1    Australia  NaN          2022-5                      Yes
# 2       Canada  NaN          2022-5                      Yes
# 3        Chile  NaN          2022-5                      Yes
# 4       Greece  NaN          2022-5                      Yes
#
#                           legislative_update_summary          hr_area  \
# 0  Roundup: Employer resources on minimum wage in...           Career
# 1     ASIC finalizes IDR data reporting requirements           Wealth
# 2  Employers to disclose electronic monitoring, i...  Career — Health
# 3                             Minimum wage increased           Career
# 4     Minimum wage increased for second time in 2022           Career
#
#                 law_in_force  \
# 0      Effective dates vary.
# 1             Beginning 2023
# 2  Effective dates vary.\n\n
# 3       Currently effective
# 4       Currently effective
#
#                                              new_law  \
# 0  In April 2021, President Joe Biden signed an e...
# 1  Final requirements from the Australian Securit...
# 2  Bill 88, the Working for Workers Act 2022, whi...
# 3  The monthly minimum wage increased on 1 Januar...
# 4  On 1 May 2022, Greece’s monthly minimum wage i...
#
#                                  impact_on_employers  \
# 0  Employers should review the changes, as they w...
# 1  Employers should review the changes, as they w...
# 2  Employers should review the changes, as they w...
# 3  Employers should review the changes, as they w...
# 4  Employers should review the changes, as they w...
#
#                                          more_info_1 more_info_2 more_info_3
# 0  Title: GRIST, regularly updated \nLink Name: G...         NaN         NaN
# 1                                                NaN         NaN         NaN
# 2  Title: Bill 88, the Working for Workers Act, 2...         NaN         NaN
# 3  Title: Announcement (Spanish) (Official Gazett...         NaN         NaN
# 4  Title: Minimum wage rises to €713 on May 1 (Ek...         NaN         NaN

# %%
data[['more_info_1_title', 'more_info_1_link_and_url']] = data['more_info_1'].str.split('\nLink Name: ', 1, expand=True)
data[['more_info_2_title', 'more_info_2_link_and_url']] = data['more_info_2'].str.split('\nLink Name: ', 1, expand=True)
data[['more_info_3_title', 'more_info_3_link_and_url']] = data['more_info_3'].str.split('\nLink Name: ', 1, expand=True)

data["more_info_1_title"] = data["more_info_1_title"].str.replace("Title:", "")
data["more_info_2_title"] = data["more_info_2_title"].str.replace("Title:", "")
data["more_info_3_title"] = data["more_info_3_title"].str.replace("Title:", "")


data[['more_info_1_link', 'more_info_1_url']] = data['more_info_1_link_and_url'].str.split('\nLink Url:', 1, expand=True)
data[['more_info_2_link', 'more_info_2_url']] = data['more_info_2_link_and_url'].str.split('\nLink Url: ', 1, expand=True)
data[['more_info_3_link', 'more_info_3_url']] = data['more_info_3_link_and_url'].str.split('\nLink Url: ', 1, expand=True)

data.drop(['more_info_1', 'more_info_2', 'more_info_3', 'more_info_1_link_and_url', 'more_info_2_link_and_url', 'more_info_3_link_and_url'], axis=1, inplace=True)
# law in force
# action required
# new_law
data["new_law"].fillna('No further details.', inplace=True)
data["employer_action_required"].fillna('N/A', inplace=True)
data["law_in_force"].fillna('No date', inplace=True)
data.fillna('', inplace=True)

# %%
# Connecting to Planet Scale
ssl_args = {'ssl_ca': "/etc/ssl/cert.pem"}

conn_string = 'mysql+pymysql://' + os.getenv("PLANETSCALE_USER") + ':' + os.getenv("PLANETSCALE_PASSWORD") + '@' + os.getenv("PLANET_SCALE_HOST") + '/' + os.getenv("PLANETSCALE_DATABASE") 

engine = create_engine(conn_string, connect_args=ssl_args)

with engine.begin() as connection:
    data.to_sql('gblu', con=connection, if_exists='replace')

# %%
with engine.begin() as connection:
    read_test = pd.read_sql("SELECT * FROM gblu", con=connection)
read_test.head()
# Out:
#    index      country flag month_of_update employer_action_required  \
# 0      0  Afghanistan               2022-5                      Yes
# 1      1    Australia               2022-5                      Yes
# 2      2       Canada               2022-5                      Yes
# 3      3        Chile               2022-5                      Yes
# 4      4       Greece               2022-5                      Yes
#
#                           legislative_update_summary          hr_area  \
# 0  Roundup: Employer resources on minimum wage in...           Career
# 1     ASIC finalizes IDR data reporting requirements           Wealth
# 2  Employers to disclose electronic monitoring, i...  Career — Health
# 3                             Minimum wage increased           Career
# 4     Minimum wage increased for second time in 2022           Career
#
#                 law_in_force  \
# 0      Effective dates vary.
# 1             Beginning 2023
# 2  Effective dates vary.\n\n
# 3       Currently effective
# 4       Currently effective
#
#                                              new_law  \
# 0  In April 2021, President Joe Biden signed an e...
# 1  Final requirements from the Australian Securit...
# 2  Bill 88, the Working for Workers Act 2022, whi...
# 3  The monthly minimum wage increased on 1 Januar...
# 4  On 1 May 2022, Greece’s monthly minimum wage i...
#
#                                  impact_on_employers  \
# 0  Employers should review the changes, as they w...
# 1  Employers should review the changes, as they w...
# 2  Employers should review the changes, as they w...
# 3  Employers should review the changes, as they w...
# 4  Employers should review the changes, as they w...
#
#                                    more_info_1_title more_info_2_title  \
# 0                          GRIST, regularly updated
# 1
# 2   Bill 88, the Working for Workers Act, 2022 (L...
# 3   Announcement (Spanish) (Official Gazette, 15 ...
# 4   Minimum wage rises to €713 on May 1 (Ekathime...
#
#   more_info_3_title                                   more_info_1_link  \
# 0                                            GRIST, regularly updated
# 1
# 2                    Bill 88, the Working for Workers Act, 2022 (Le...
# 3                    Announcement (Spanish) (Official Gazette, 15 J...
# 4                    Minimum wage rises to €713 on May 1 (Ekathimer...
#
#                                      more_info_1_url more_info_2_link  \
# 0   https://www.mercer.com/our-thinking/law-and-p...
# 1
# 2   https://www.ola.org/en/legislative-business/b...
# 3   https://www.diariooficial.interior.gob.cl/pub...
# 4   https://www.ekathimerini.com/economy/1182748/...
#
#   more_info_2_url more_info_3_link more_info_3_url
# 0
# 1
# 2
# 3
# 4
